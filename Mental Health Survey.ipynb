# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from config import api_key
from scipy import stats
import json

url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&units={units}&q="
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       8 import json
#      10 url = "http://api.openweathermap.org/data/2.5/weather?"
# ---> 11 query_url = f"{url}appid={api_key}&units={units}&q="
#
# NameError: name 'units' is not defined

# %%
import requests

url = "https://mental-health-care-file.p.rapidapi.com/records"

querystring = {"orderBy":"dataListIndex_asc","limit":"500","index":"0"}

headers = {
	"x-rapidapi-key": "6c2ed8f677msh87bcc5d62dfdbd1p1105a6jsndbcfd881ed46",
	"x-rapidapi-host": "mental-health-care-file.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'dataListIndex': '0', 'indicator': 'Took Prescription Medication for Mental Health, Last 4 Weeks', 'group': 'National Estimate', 'state': 'United States', 'subgroup': 'United States', 'phase': '2', 'timePeriod': '13', 'timePeriodLabel': 'Aug 19 - Aug 31, 2020', 'timePeriodStartDate': '08/19/2020', 'timePeriodEndDate': '08/31/2020', 'value': '19.4', 'lowci': '19.0', 'highci': '19.8', 'confidenceInterval': '19.0 - 19.8', 'quartileRange': '', 'suppressionFlag': ''}, {'dataListIndex': '1', 'indicator': 'Took Prescription Medication for Mental Health, Last 4 Weeks', 'group': 'By Age', 'state': 'United States', 'subgroup': '18 - 29 years', 'phase': '2', 'timePeriod': '13', 'timePeriodLabel': 'Aug 19 - Aug 31, 2020', 'timePeriodStartDate': '08/19/2020', 'timePeriodEndDate': '08/31/2020', 'value': '18.7', 'lowci': '17.2', 'highci': '20.3', 'confidenceInterval': '17.2 - 20.3', 'quartileRange': '', 'suppressionFlag': ''}, {'dataListIndex': '10', 'indicator': 'Took Prescription Medic
# ...

# %%
pretty_printed_json = json.dumps(response.json(), indent=4)
print(pretty_printed_json)
# Out:
# {
#     "data": [
#         {
#             "dataListIndex": "0",
#             "indicator": "Took Prescription Medication for Mental Health, Last 4 Weeks",
#             "group": "National Estimate",
#             "state": "United States",
#             "subgroup": "United States",
#             "phase": "2",
#             "timePeriod": "13",
#             "timePeriodLabel": "Aug 19 - Aug 31, 2020",
#             "timePeriodStartDate": "08/19/2020",
#             "timePeriodEndDate": "08/31/2020",
#             "value": "19.4",
#             "lowci": "19.0",
#             "highci": "19.8",
#             "confidenceInterval": "19.0 - 19.8",
#             "quartileRange": "",
#             "suppressionFlag": ""
#         },
#         {
#             "dataListIndex": "1",
#             "indicator": "Took Prescription Medication for Mental Health, Last 4 Weeks",
#             "group": "By Age",
#             "state": "United States",
#             "subgroup": "18 - 29 years",
# ...
